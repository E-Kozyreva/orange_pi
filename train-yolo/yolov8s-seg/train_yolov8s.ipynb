# %% [markdown]
# ### Clone repository

# %%
# !git clone https://github.com/ultralytics/JSON2YOLO

# %% [markdown]
# ### Install libs

# %%
# %pip install -r "./JSON2YOLO/requirements.txt"

# %%
# %pip install ultralytics

# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117

# %% [markdown]
# ### Check CUDA

# %%
import torch
torch.cuda.is_available()

# %% [markdown]
# ### Connect ClearMl

# %%
from clearml import Task, Logger

# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=JKJ85HIW6ZZIYW0ZTCRD
# %env CLEARML_API_SECRET_KEY=PB2RjuAEw0YR8eRg4ljf8bOZ0tuROT0IpGxDNRrGLE9zrSPRBI
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=JKJ85HIW6ZZIYW0ZTCRD
# env: CLEARML_API_SECRET_KEY=PB2RjuAEw0YR8eRg4ljf8bOZ0tuROT0IpGxDNRrGLE9zrSPRBI

# %%
task = Task.init(
    project_name='ai_road_detect', 
    task_name='seg_100_yolov8s')
# Out:
# ClearML Task: created new task id=0a280395a992407a800184b552384a2c
# 2023-08-20 22:21:58,789 - clearml.Repository Detection - WARNING - Could not read Jupyter Notebook: No module named 'nbconvert'
# 2023-08-20 22:21:58,825 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.clear.ml/projects/a0640b25fb1649f4854b744f2ebf9e95/experiments/0a280395a992407a800184b552384a2c/output/log

# %% [markdown]
# ### Train model

# %%
from ultralytics import YOLO
import torch
import gc

# %%
model = YOLO('F:/work_ai_road_detection/ai_road_detection_test_branch/training/runs/segment/300 epoch/weights/best.pt')

results = model.train(
   data='dataset/data.yaml',
   imgsz=640,
   epochs=100,
   batch=14,
   device=0,
   name='400 epoch'
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.158 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.157  Python-3.8.0 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 2070 SUPER, 8192MiB)
# ...

# %% [markdown]
# ### If we have cuda out of memory use it

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ### Prediction

# %%
model = YOLO('F:/work_ai_road_detection/ai_road_detection_test_branch/training/runs/segment/400 epoch/weights/best.pt')         

pre = model.predict(
    source="F:/work_ai_road_detection/ai_road_detection_test_branch/training/test_data/004.mp4", 
    name="test_4e400c2",
    imgsz=640,                                                                                     
    save=True,                                                                                              
    conf=0.2,
    boxes=True,                                                   
)
# Out:
#     WARNING  stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/366) F:\work_ai_road_detection\ai_road_detection_test_branch\training\test_data\004.mp4: 384x640 4 cars, 65.5ms
# video 1/1 (2/366) F:\work_ai_road_detection\ai_road_detection_test_branch\training\test_data\004.mp4: 384x640 3 cars, 1 sign, 11.0ms
# video 1/1 (3/366) F:\work_ai_road_detection\ai_road_detection_test_branch\training\test_data\004.mp4: 384x640 3 cars, 2 signs, 10.0ms
# ...
